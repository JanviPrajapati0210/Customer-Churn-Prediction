# %% [markdown]
# ## Feature Enginnering

# %%
# Balance per product
df['Balance_per_product']=df['balance']/df['products_number'].replace(0,np.nan)
df['Balance_per_product'].fillna(0,inplace=True)

# Salary to balance ratio
df['salary_balance_ratio']=df['estimated_salary']/df['balance'].replace(0,np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Balance per product
# ----> 2 df['Balance_per_product']=df['balance']/df['products_number'].replace(0,np.nan)
#       3 df['Balance_per_product'].fillna(0,inplace=True)
#       5 # Salary to balance ratio
#
# NameError: name 'df' is not defined
